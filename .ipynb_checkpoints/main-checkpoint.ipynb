# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
import shutil

import time
import pandas as pd
from tqdm import tqdm

from itertools import compress

import re

# %%
# 0. 환경설정 및 세팅
try:
    shutil.rmtree(r"c:\chrometemp")  #쿠키 / 캐쉬파일 삭제
except FileNotFoundError:
    pass

PATH = r"C:\Users\NH\Documents\chromedriver-win64\chromedriver-win64\chromedriver.exe"
driver=webdriver.Chrome(PATH)
# Out:
# C:\Users\NH\AppData\Local\Temp\ipykernel_25104\78490518.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(PATH)

# %%
# 1. 날짜와 마지막 페이지 지정
start_day = '2023-09-20'
max_page = 219 # 이거 설정하지 않아도 되는 법 고민

# %%
def elementToTextList(class_name):
    results = []
    elements = driver.find_elements(By.CLASS_NAME,class_name)
    for element in elements:
        element = element.text.split('\n')
        results.append(element)
    return results

# %%
def pagePaser():
    mul_list_txt_box = elementToTextList("mul-list-txt-box")
    mul_list_img_box = elementToTextList("mul-list-img-box")
    mul_list = [mul_list_txt_box,mul_list_img_box]
    return mul_list

# %%
df_list = []
for page in tqdm(range(0,max_page*60,60)):
    target_url = 'https://madangs.com/search?addr=&court=&asset_classification=7+10+8+6+1+2+5+3&build_area_max=0&build_area_min=0&disposal_method=0&eval_p_max=0&eval_p_min=0&g_use_type=&land_area_max=0&land_area_min=0&list_type=0&low_p_max=0&low_p_min=0&state=10&g_state=10+20&share=2&g_share=2&special=&contain_special=0&uchal=&use_type=&sort=bd_desc&start_date={}&end_date=&page={}'.format(start_day, page)
    driver.get(target_url)
    df = pagePaser()
    while len(df[0]) == 0:
        df = pagePaser()
    df_list.append(df)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 219/219 [14:02<00:00,  3.85s/it]

# %%
def datapre(mul_list_txt_box,mul_list_img_box):
    tags_list = []
    rent_list = []
    for x in mul_list_txt_box:
        idx = ['#' in y for y in x ]
        tags = list(compress(x, idx))
        [x.remove(t) for t in tags]
        tags = ''.join(tags)
        tags_list.append(tags)
    
    for x in mul_list_txt_box:
        idx = ['%)' in y for y in x ]
        tags = list(compress(x, idx))
        [x.remove(t) for t in tags]
        
    for x in mul_list_img_box:
        if '임대' in x:
            x.remove('임대')
            rent_list.append(True)
        else:
            rent_list.append(False)         

    for x in mul_list_txt_box:
        if '진행중' in x:
            x.reverse()
            x.append('미정')
            x.reverse()

    for x in mul_list_txt_box:
        if '입찰마감' in x[0]:
            x.reverse()
            x.append('미정')
            x.reverse()
            
    df = pd.DataFrame(mul_list_txt_box,columns = ['법원명','사건번호','매각기일','주소','감정가','최저가'])
    df2 = pd.DataFrame(mul_list_img_box,columns = ['주거형태','건물평수','조회수','경매/공매'])
    df['태그'] = tags_list
    df2['임대여부'] = rent_list
    df = pd.concat([df,df2], axis = 1)
    return df

# %%
dfs = []
for idx, _ in enumerate(df_list):
    df = datapre(df_list[idx][0],df_list[idx][1])
    dfs.append(df)

# %%
dfs = pd.concat(dfs)

# %%
dfs = dfs.drop_duplicates().reset_index(drop = True)

# %%
dfs = dfs.dropna()

# %%
def korean_to_int(korean):
    parts = re.split("(억|만|원)", korean)
    tmp = []
    for x in parts:
        while len(x) != 4:
            x = '0' + x
        tmp.append(x)

    tmp = tmp[:-1]

    tmp = [x for x in tmp if '억' not in x]
    tmp = [x for x in tmp if '만' not in x]
    tmp = [x for x in tmp if '원' not in x]

    result = int(''.join(tmp))
    return result

# %%
tmp = []
for x in dfs['감정가']:
    if x == '-':
        result = 0
        tmp.append(result)
    else:
        result = korean_to_int(x)
        tmp.append(result)

# %%
dfs['감정가'] = tmp

# %%
tmp = []
for x in dfs['최저가']:
    if x == '-':
        result = 0
        tmp.append(result)
    elif x == '비공개':
        result = 0
        tmp.append(result)
    else:
        result = korean_to_int(x)
        tmp.append(result)

# %%
dfs['최저가'] = tmp

# %%
dfs
# Out:
#           법원명              사건번호  매각기일  \
# 0        진주지원     2021타경1550[1]  D-57
# 1      서울남부지법      2022타경156[1]  D-56
# 2      서울남부지법   2022타경102168[1]  D-56
# 3      서울남부지법   2022타경114307[1]  D-56
# 4        서산지원    2022타경56959[1]  D-55
# ...       ...               ...   ...
# 13115  부산서부지원  2022타경107563[22]  결과대기
# 13116  부산서부지원  2022타경107563[23]  결과대기
# 13117  부산서부지원  2022타경107563[24]  결과대기
# 13118  부산서부지원  2022타경107563[28]  결과대기
# 13119  부산서부지원  2022타경107563[32]  결과대기
#
#                                                       주소         감정가  \
# 0                                    경상남도 산청군 산청읍 차탄리 산9  2049266000
# 1                                서울특별시 영등포구 영등포로65길 15-1  1218785600
# 2           서울특별시 강서구 공항대로55길 10-3, 제6층 제602호 (등촌동, 워너빌)   124480000
# 3      서울특별시 영등포구 경인로112길 4-7, 제6층 제601호 (영등포동1가, 메트로가든)   139000000
# 4                                   충청남도 당진시 고대면 용두리 326   104047980
# ...                                                  ...         ...
# 13115              부산광역시 사상구 주례로 22, 6층602호 (주례동,베스아이하늘)   118000000
# 13116              부산광역시 사상구 주례로 22, 6층603호 (주례동,베스아이하늘)   117000000
# 13117              부산광역시 사상구 주례로 22, 6층604호 (주례동,베스아이하늘)   109000000
# 13118              부산광역시 사상구 주례로 22, 7층703호 (주례동,베스아이하늘)   117000000
# 13119              부산광역시 사상구 주례로 22, 8층802호 (주례동,베스아이하늘)   120000000
#
#              최저가                        태그      주거형태    건물평수        조회수 경매/공매  \
# 0      275048000        #유찰9회#재매각#분묘기지권#맹지        임야  20228평   view 508    경매
# 1      975028000                     #유찰1회       다가구     73평  view 2.6k    경매
# 2       40790000  #유찰5회#선순위임차인#위반건축물#임차권등기       다세대      6평   view 429    경매
# 3      111200000                     #유찰1회  오피스텔(주거)      4평   view 344    경매
# 4       35689000                     #유찰3회      단독주택     20평   view 550    경매
# ...          ...                       ...       ...     ...        ...   ...
# 13115  118000000                       #신건  오피스텔(사무)      7평     view 2    경매
# 13116  117000000                       #신건  오피스텔(사무)      7평     view 2    경매
# 13117  109000000                       #신건  오피스텔(사무)      7평     view 2    경매
# 13118  117000000                       #신건  오피스텔(사무)      7평     view 2    경매
# 13119  120000000                       #신건  오피스텔(사무)      7평     view 2    경매
#
#         임대여부
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 13115  False
# 13116  False
# 13117  False
# 13118  False
# 13119  False
#
# [13120 rows x 12 columns]

# %%
tmp = []
for x in dfs['조회수']:
    if 'k' in x:
        x = x.replace('view','')
        x = x.replace('k','')
        x = int(float(x)*1000)
        tmp.append(x)
    else:
        x = int(x.replace('view',''))
        tmp.append(x)

# %%
dfs['조회수'] = tmp

# %%
dfs['건물평수'] = [x.replace('평','') for x in dfs['건물평수']]

# %%
dfs['할인율'] = round((dfs['감정가'] - dfs['최저가']) / dfs['감정가'],2)

# %%
dfs
# Out:
#           법원명              사건번호  매각기일  \
# 0        진주지원     2021타경1550[1]  D-57
# 1      서울남부지법      2022타경156[1]  D-56
# 2      서울남부지법   2022타경102168[1]  D-56
# 3      서울남부지법   2022타경114307[1]  D-56
# 4        서산지원    2022타경56959[1]  D-55
# ...       ...               ...   ...
# 13115  부산서부지원  2022타경107563[22]  결과대기
# 13116  부산서부지원  2022타경107563[23]  결과대기
# 13117  부산서부지원  2022타경107563[24]  결과대기
# 13118  부산서부지원  2022타경107563[28]  결과대기
# 13119  부산서부지원  2022타경107563[32]  결과대기
#
#                                                       주소         감정가  \
# 0                                    경상남도 산청군 산청읍 차탄리 산9  2049266000
# 1                                서울특별시 영등포구 영등포로65길 15-1  1218785600
# 2           서울특별시 강서구 공항대로55길 10-3, 제6층 제602호 (등촌동, 워너빌)   124480000
# 3      서울특별시 영등포구 경인로112길 4-7, 제6층 제601호 (영등포동1가, 메트로가든)   139000000
# 4                                   충청남도 당진시 고대면 용두리 326   104047980
# ...                                                  ...         ...
# 13115              부산광역시 사상구 주례로 22, 6층602호 (주례동,베스아이하늘)   118000000
# 13116              부산광역시 사상구 주례로 22, 6층603호 (주례동,베스아이하늘)   117000000
# 13117              부산광역시 사상구 주례로 22, 6층604호 (주례동,베스아이하늘)   109000000
# 13118              부산광역시 사상구 주례로 22, 7층703호 (주례동,베스아이하늘)   117000000
# 13119              부산광역시 사상구 주례로 22, 8층802호 (주례동,베스아이하늘)   120000000
#
#              최저가                        태그      주거형태   건물평수   조회수 경매/공매  \
# 0      275048000        #유찰9회#재매각#분묘기지권#맹지        임야  20228   508    경매
# 1      975028000                     #유찰1회       다가구     73  2600    경매
# 2       40790000  #유찰5회#선순위임차인#위반건축물#임차권등기       다세대      6   429    경매
# 3      111200000                     #유찰1회  오피스텔(주거)      4   344    경매
# 4       35689000                     #유찰3회      단독주택     20   550    경매
# ...          ...                       ...       ...    ...   ...   ...
# 13115  118000000                       #신건  오피스텔(사무)      7     2    경매
# 13116  117000000                       #신건  오피스텔(사무)      7     2    경매
# 13117  109000000                       #신건  오피스텔(사무)      7     2    경매
# 13118  117000000                       #신건  오피스텔(사무)      7     2    경매
# 13119  120000000                       #신건  오피스텔(사무)      7     2    경매
#
#         임대여부   할인율
# 0      False  0.87
# 1      False  0.20
# 2      False  0.67
# 3      False  0.20
# 4      False  0.66
# ...      ...   ...
# 13115  False  0.00
# 13116  False  0.00
# 13117  False  0.00
# 13118  False  0.00
# 13119  False  0.00
#
# [13120 rows x 13 columns]

# %%
dfs.to_csv('data.csv',index = False)
